# %%
import pandas as pd

# %%
ls
# Out:
# Clark-feedback.md   colname_index.md    hhs_ca.csv          samples.csv
# README.md           description.md      map.R               usaspending-sql.md
# aff_download.zip    example.ipynb       proposal.md
# clean.csv           explore .ipynb      sample.csv

# %%
df = pd.read_csv("hhs_ca.csv")
# Out:
# /Users/katietruong/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19,23,24,26,32,39,42,43,44,45,46,47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(df)
# Out:
# ['Unnamed: 0',
#  'recipient_unique_id',
#  'transaction_id',
#  'action_date',
#  'last_modified_date',
#  'fiscal_year',
#  'award_id',
#  'generated_pragmatic_obligation',
#  'total_obligation',
#  'total_subsidy_cost',
#  'total_loan_value',
#  'total_obl_bin',
#  'federal_action_obligation',
#  'original_loan_subsidy_cost',
#  'face_value_loan_guarantee',
#  'recipient_id',
#  'recipient_hash',
#  'awarding_agency_id',
#  'funding_agency_id',
#  'type',
#  'action_type',
#  'award_category',
#  'fain',
#  'uri',
#  'piid',
#  'transaction_description',
#  'modification_number',
#  'pop_country_code',
#  'pop_country_name',
#  'pop_state_code',
#  'pop_county_code',
#  'pop_county_name',
#  'pop_zip5',
#  'pop_congressional_code',
#  'recipient_location_country_code',
#  'recipient_location_country_name',
#  'recipient_location_state_code',
#  'recipient_location_county_code',
#  'recipient_location_county_name',
#  'recipient_location_congressional_code',
# ...

# %%
cols_to_drop = [0, 26, 27, 28, 29, 30, 31]
df.drop(df.columns[cols_to_drop],axis=1,inplace=True)

# %%
df
# Out:
#         recipient_unique_id  transaction_id action_date last_modified_date  \
# 0                 1018675.0        17659395  2009-06-01         2015-08-05
# 1                 1018675.0        81139689  2017-11-29         2018-05-21
# 2                 1018675.0        57102896  2015-09-28         2017-01-27
# 3                 1018675.0        60639270  2016-09-15         2017-01-27
# 4                 1018675.0        88430092  2017-08-15         2017-08-21
# 5                 1184480.0        48613174  2010-01-21         2014-02-18
# 6                 1184480.0        34108169  2010-01-21         2011-11-01
# 7                 1184480.0        47350159  2010-01-21         2014-02-18
# 8                 1184480.0        16634771  2012-10-25         2013-04-18
# 9                 1184480.0        32116073  2012-10-24         2014-02-18
# 10                1184480.0        48107337  2012-10-24         2014-02-18
# ...

# %%
df['total_obligation']
# Out:
# 0         4.468000e+03
# 1         5.749700e+05
# 2         7.500000e+04
# 3         5.749700e+05
# 4         5.749700e+05
# 5         2.462500e+04
# 6         2.212000e+02
# 7         3.064320e+03
# 8         3.007375e+04
# 9         2.028676e+04
# 10        3.180600e+03
# 11        2.067370e+03
# 12        4.000080e+03
# 13        6.695960e+03
# 14        1.419228e+04
# 15        3.735564e+04
# 16        1.673704e+04
# 17        7.363200e+03
# 18        3.780000e+03
# 19        6.371650e+03
# 20        0.000000e+00
# 21        8.161900e+03
# 22        7.158700e+02
# 23        7.616000e+03
# 24        1.140000e+04
# 25        2.649750e+04
# 26        2.204500e+02
# 27        9.359280e+03
# 28        6.830880e+03
# 29        7.500000e+03
#               ...
# 338482    4.692500e+05
# 338483    3.506000e+04
# 338484    3.102750e+05
# 338485    2.878500e+05
# 338486    1.836850e+05
# 338487    2.621200e+05
# 338488    2.435780e+05
# 338489    7.439900e+04
# 338490    3.060000e+05
# ...

# %%
df['recipient_location_county_name']
# Out:
# 0                         YOLO
# 1                         YOLO
# 2                         YOLO
# 3                         YOLO
# 4                         YOLO
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                   SAN MATEO
# 15                   SAN MATEO
# 16                   SAN MATEO
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                   SAN MATEO
# 24                   SAN MATEO
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ...

# %%
df.to_csv('clean.csv')

# %%
import os
os.stat('clean.csv')
# Out:
# os.stat_result(st_mode=33188, st_ino=1636138, st_dev=16777220, st_nlink=1, st_uid=501, st_gid=20, st_size=191226606, st_atime=1552511540, st_mtime=1552511571, st_ctime=1552511571)

# %%
df = pd.read_csv("clean.csv")
# Out:
# /Users/katietruong/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (19,23,24,26,33,36,37,38,39,40,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0  recipient_unique_id  transaction_id action_date  \
# 0                0            1018675.0        17659395  2009-06-01
# 1                1            1018675.0        81139689  2017-11-29
# 2                2            1018675.0        57102896  2015-09-28
# 3                3            1018675.0        60639270  2016-09-15
# 4                4            1018675.0        88430092  2017-08-15
# 5                5            1184480.0        48613174  2010-01-21
# 6                6            1184480.0        34108169  2010-01-21
# 7                7            1184480.0        47350159  2010-01-21
# 8                8            1184480.0        16634771  2012-10-25
# 9                9            1184480.0        32116073  2012-10-24
# 10              10            1184480.0        48107337  2012-10-24
# 11              11            1184480.0        22861891  2012-10-24
# 12              12            1184480.0        45987098  2010-01-25
# ...

# %%
df.groupby(['fiscal_year','recipient_location_county_name'])['total_obligation'].sum().reset_index()
# Out:
#       fiscal_year recipient_location_county_name  total_obligation
# 0            2001                        ALAMEDA      1.271008e+08
# 1            2001                         AMADOR      4.150030e+05
# 2            2001                          BUTTE     -3.268204e+06
# 3            2001                      CALAVERAS      1.588388e+06
# 4            2001                         COLUSA      6.809320e+05
# 5            2001                   CONTRA COSTA     -2.091900e+04
# 6            2001                      EL DORADO      2.313788e+06
# 7            2001                         FRESNO     -1.308242e+07
# 8            2001                          GLENN      7.203510e+05
# 9            2001                       HUMBOLDT      8.216737e+06
# 10           2001                       IMPERIAL      4.171004e+06
# 11           2001                           INYO      5.011330e+05
# 12           2001                           KERN     -8.690856e+06
# ...
